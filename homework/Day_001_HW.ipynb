# %% [markdown]
# # 作業一 Trending Youtube Video Statistics
# ## 1. Youtube已經變成每個人每天娛樂、紓壓的重要來源，分析Youtube何種影片的點閱、觀看是最受歡迎的，以及分析何種要素是可能讓一支影片變得熱門，這些都有助於Youtube針對個人推播客製化的影片。
# ## 2. 資料來源是Youtube上的影片 提供者是Mitchell J 利用Youtube提供的 Data API蒐集
# ## 3.蒐集來源為非結構資料的影片 蒐集出來為JSON檔案
# ## 4.不同種類的影片如何影響使用者的喜好→預測哪些影片會獲得點擊: Accuracy / Receiver Operating Curve, ROC

# %% [markdown]
# # 作業二
# ## 1.提升業績我認為是指在一週、月、年等固定時間內，載客數有顯著上升，假設某個時段是最多人需要交通工具的時候，車行便在這些時段派駐最多車子駐點
# ## 2. 以下是我認為有影響的資料: (1)何種時段的載客數最多 (2)哪個地區的載客數最多
# ## (3)客戶支付車資的方式: 現金、行動支付、信用卡等 (4)客戶的年齡層分布。
# ## 蒐集的方法我認為有 (1)透過App紀錄客戶資訊 (2)司機詢問客戶意願進而蒐集
# ## 3.資料型態我認為有 (1)App紀錄的結構化資料 (2)司機詢問的非結構化資料
# ## 4. 不同時段的載客數(ex:學生族群上下課時間駐點): 搭乘客戶預測→哪個時段明顯有較多的人需要交通工具: Accuracy / Receiver Operating Curve, ROC

# %% [markdown]
# # 作業三 Mean Squared Error

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0,100,101)
y = (x_lin+np.random.randn(101)*5) * w + b
plt.plot(x_lin,y,'b.',label='data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin*w+b
plt.plot(x_lin,y,'b.',label = 'data')
plt.plot(x_lin,y_hat,'r-',label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# # Mean Squared Error(MSE)

# %%
def mean_squared_error(y,yp):
    """ 
        計算MSE
        Args: 
            -y:實際值
            -yp:預測值
        Return:
            -mse:MSE
    """
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse
MSE = mean_squared_error(y,y_hat)
print("The Mean Squared error is %.3f" %(MSE))
# Out:
# The Mean Squared error is 220.612
